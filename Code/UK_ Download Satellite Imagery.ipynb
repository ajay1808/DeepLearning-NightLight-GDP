# %% [markdown]
# '''
# This is a sample notebook. Copy this and Create a new notebook underyour name
# '''

# %%
# rasterio - 1.3.5
# fiona - 1.8.22
# geopandas - 0.12.2

# %%
#mounting google drive to access the dataset 
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !ls "/content/gdrive/MyDrive/ADS Project/VNP46A3_UK"

# %%
'''
Go to https://ladsweb.modaps.eosdis.nasa.gov/

Create your login: you will need your account to downloads the data

Click find data

Select Nighttime lights on the left and then select VNP46A2
https://ladsweb.modaps.eosdis.nasa.gov/missions-and-measurements/products/VNP46A2/ (read to get familiar to dataset)

Select time, location and then select all files 

then submit, wait 10 mins and go to past orders, files should be ready to download

copy the wget command to download data

replace the dot at the end with your download path

This example is for hurricane Michael

'''

download_path = "/content/gdrive/MyDrive/ADS Project/VNP46A3_UK" #path to your download folder

# %%
# !wget -e robots=off -m -np -R .html,.tmp -nH --cut-dirs=3 "https://ladsweb.modaps.eosdis.nasa.gov/archive/orders/501961928/" --header "Authorization: Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJBUFMgT0F1dGgyIEF1dGhlbnRpY2F0b3IiLCJpYXQiOjE2ODI3MzYxMDQsIm5iZiI6MTY4MjczNjEwNCwiZXhwIjoxNjk4Mjg4MTA0LCJ1aWQiOiJ5dXpldG9oIiwiZW1haWxfYWRkcmVzcyI6Inl1emV0b2hAZ21haWwuY29tIiwidG9rZW5DcmVhdG9yIjoieXV6ZXRvaCJ9.umM5U8ewxpAcptpBC1O0FoFxKiRp4oIqpqkpoQ4pv58" -P "/content/gdrive/MyDrive/ADS Project/VNP46A3_UK"
# Out:
# --2023-04-29 02:42:39--  https://ladsweb.modaps.eosdis.nasa.gov/archive/orders/501961928/
# Resolving ladsweb.modaps.eosdis.nasa.gov (ladsweb.modaps.eosdis.nasa.gov)... 198.118.194.40, 2001:4d0:241a:40c0::40
# Connecting to ladsweb.modaps.eosdis.nasa.gov (ladsweb.modaps.eosdis.nasa.gov)|198.118.194.40|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 31907 (31K) [text/html]
# Saving to: ‘/content/gdrive/MyDrive/ADS Project/VNP46A3_UK/index.html.tmp’
#
# index.html.tmp      100%[===================>]  31.16K  --.-KB/s    in 0.002s
#
# Last-modified header missing -- time-stamps turned off.
# 2023-04-29 02:42:40 (19.7 MB/s) - ‘/content/gdrive/MyDrive/ADS Project/VNP46A3_UK/index.html.tmp’ saved [31907/31907]
#
# Removing /content/gdrive/MyDrive/ADS Project/VNP46A3_UK/index.html.tmp since it should be rejected.
#
# --2023-04-29 02:42:40--  https://ladsweb.modaps.eosdis.nasa.gov/archive/orders/501961928/checksums_501961928
# Reusing existing connection to ladsweb.modaps.eosdis.nasa.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 20645 (20K) [text/html]
# Saving to: ‘/content/gdrive/MyDrive/ADS Project/VNP46A3_UK/checksums_501961928’
#
# checksums_501961928 100%[===================>]  20.16K  --.-KB/s    in 0.002s
#
# Last-modified header missing -- time-stamps turned off.
# 2023-04-29 02:42:40 (11.7 MB/s) - ‘/content/gdrive/MyDrive/ADS Project/VNP46A3_UK/checksums_501961928’ saved [20645/20645]
#
# --2023-04-29 02:42:40--  https://ladsweb.modaps.eosdis.nasa.gov/archive/orders/501961928/VNP46A3.A2023001.h17v02.001.2023039140650.h5
# Reusing existing connection to ladsweb.modaps.eosdis.nasa.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 827634 (808K) [application/octet-stream]
# Saving to: ‘/content/gdrive/MyDrive/ADS Project/VNP46A3_UK/VNP46A3.A2023001.h17v02.001.2023039140650.h5’
#
# VNP46A3.A2023001.h1 100%[===================>] 808.24K  --.-KB/s    in 0.03s
#
# 2023-04-29 02:42:41 (28.5 MB/s) - ‘/content/gdrive/MyDrive/ADS Project/VNP46A3_UK/VNP46A3.A2023001.h17v02.001.2023039140650.h5’ saved [827634/827634]
#
# --2023-04-29 02:42:41--  https://ladsweb.modaps.eosdis.nasa.gov/archive/orders/501961928/VNP46A3.A2023001.h17v03.001.2023039141229.h5
# Reusing existing connection to ladsweb.modaps.eosdis.nasa.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 14096353 (13M) [application/octet-stream]
# Saving to: ‘/content/gdrive/MyDrive/ADS Project/VNP46A3_UK/VNP46A3.A2023001.h17v03.001.2023039141229.h5’
#
# VNP46A3.A2023001.h1 100%[===================>]  13.44M  41.5MB/s    in 0.3s
#
# 2023-04-29 02:42:42 (41.5 MB/s) - ‘/content/gdrive/MyDrive/ADS Project/VNP46A3_UK/VNP46A3.A2023001.h17v03.001.2023039141229.h5’ saved [14096353/14096353]
#
# --2023-04-29 02:42:42--  https://ladsweb.modaps.eosdis.nasa.gov/archive/orders/501961928/VNP46A3.A2023001.h17v04.001.2023039142158.h5
# Reusing existing connection to ladsweb.modaps.eosdis.nasa.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 13230800 (13M) [application/octet-stream]
# Saving to: ‘/content/gdrive/MyDrive/ADS Project/VNP46A3_UK/VNP46A3.A2023001.h17v04.001.2023039142158.h5’
#
# VNP46A3.A2023001.h1 100%[===================>]  12.62M  7.78MB/s    in 1.6s
#
# 2023-04-29 02:42:44 (7.78 MB/s) - ‘/content/gdrive/MyDrive/ADS Project/VNP46A3_UK/VNP46A3.A2023001.h17v04.001.2023039142158.h5’ saved [13230800/13230800]
#
# --2023-04-29 02:42:44--  https://ladsweb.modaps.eosdis.nasa.gov/archive/orders/501961928/VNP46A3.A2023001.h18v03.001.2023039142536.h5
# Reusing existing connection to ladsweb.modaps.eosdis.nasa.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 14130832 (13M) [application/octet-stream]
# Saving to: ‘/content/gdrive/MyDrive/ADS Project/VNP46A3_UK/VNP46A3.A2023001.h18v03.001.2023039142536.h5’
#
# VNP46A3.A2023001.h1 100%[===================>]  13.48M  48.9MB/s    in 0.3s
#
# 2023-04-29 02:42:45 (48.9 MB/s) - ‘/content/gdrive/MyDrive/ADS Project/VNP46A3_UK/VNP46A3.A2023001.h18v03.001.2023039142536.h5’ saved [14130832/14130832]
#
# --2023-04-29 02:42:45--  https://ladsweb.modaps.eosdis.nasa.gov/archive/orders/501961928/VNP46A3.A2023001.h18v04.001.2023039142938.h5
# Reusing existing connection to ladsweb.modaps.eosdis.nasa.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 25207175 (24M) [application/octet-stream]
# Saving to: ‘/content/gdrive/MyDrive/ADS Project/VNP46A3_UK/VNP46A3.A2023001.h18v04.001.2023039142938.h5’
#
# VNP46A3.A2023001.h1 100%[===================>]  24.04M  45.9MB/s    in 0.5s
#
# 2023-04-29 02:42:46 (45.9 MB/s) - ‘/content/gdrive/MyDrive/ADS Project/VNP46A3_UK/VNP46A3.A2023001.h18v04.001.2023039142938.h5’ saved [25207175/25207175]
#
# --2023-04-29 02:42:47--  https://ladsweb.modaps.eosdis.nasa.gov/archive/orders/501961928/checksums_501961928/
# Reusing existing connection to ladsweb.modaps.eosdis.nasa.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 20645 (20K) [text/html]
# Saving to: ‘/content/gdrive/MyDrive/ADS Project/VNP46A3_UK/checksums_501961928/index.html.tmp’
#
# checksums_501961928 100%[===================>]  20.16K  --.-KB/s    in 0.002s
#
# Last-modified header missing -- time-stamps turned off.
# 2023-04-29 02:42:47 (10.9 MB/s) - ‘/content/gdrive/MyDrive/ADS Project/VNP46A3_UK/checksums_501961928/index.html.tmp’ saved [20645/20645]
#
# Removing /content/gdrive/MyDrive/ADS Project/VNP46A3_UK/checksums_501961928/index.html.tmp since it should be rejected.
#
# FINISHED --2023-04-29 02:42:47--
# Total wall clock time: 7.3s
# Downloaded: 8 files, 64M in 2.8s (23.2 MB/s)

# %%
'''
Next step go to processing notebook and save as tiff files
'''
# Out:
# '\nNext step go to processing notebook and save as tiff files\n'
