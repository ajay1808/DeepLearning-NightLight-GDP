# %% [markdown]
# '''
# This is a sample notebook. Copy this and Create a new notebook underyour name
# '''

# %%
# rasterio - 1.3.5
# fiona - 1.8.22
# geopandas - 0.12.2

# %%
#mounting google drive to access the dataset 
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ls "gdrive/MyDrive/CUSP Capstone Power Outage/Data/Praateek/VNP46A2"

# %%
'''
Go to https://ladsweb.modaps.eosdis.nasa.gov/

Create your login: you will need your account to downloads the data

Click find data

Select Nighttime lights on the left and then select VNP46A2
https://ladsweb.modaps.eosdis.nasa.gov/missions-and-measurements/products/VNP46A2/ (read to get familiar to dataset)

Select time, location and then select all files 

then submit, wait 10 mins and go to past orders, files should be ready to download

copy the wget command to download data

replace the dot at the end with your download path

This example is for hurricane Michael

'''

download_path = "gdrive/MyDrive/CUSP Capstone Power Outage/Data/Prateek/VNP46A2" #path to your download folder

# %%
# !wget -e robots=off -m -np -R .html,.tmp -nH --cut-dirs=3 "https://ladsweb.modaps.eosdis.nasa.gov/archive/orders/501904002/" --header "Authorization: Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJBUFMgT0F1dGgyIEF1dGhlbnRpY2F0b3IiLCJpYXQiOjE2NzQ2NjM0NDIsIm5iZiI6MTY3NDY2MzQ0MiwiZXhwIjoxNjkwMjE1NDQyLCJ1aWQiOiJwcmF0ZWVrNDBhIiwiZW1haWxfYWRkcmVzcyI6InBhMjE3OEBueXUuZWR1IiwidG9rZW5DcmVhdG9yIjoicHJhdGVlazQwYSJ9.8SonVxq0aYEvo9BaGvjmCezmxsLPZlLttmE96ZqXYto" -P "gdrive/MyDrive/CUSP Capstone Power Outage/Data/Prateek/VNP46A2"
# Out:
# --2023-01-25 16:33:52--  https://ladsweb.modaps.eosdis.nasa.gov/archive/orders/501904002/
# Resolving ladsweb.modaps.eosdis.nasa.gov (ladsweb.modaps.eosdis.nasa.gov)... 198.118.194.40, 2001:4d0:241a:40c0::40
# Connecting to ladsweb.modaps.eosdis.nasa.gov (ladsweb.modaps.eosdis.nasa.gov)|198.118.194.40|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85250 (83K) [text/html]
# Saving to: ‘gdrive/MyDrive/CUSP Capstone Power Outage/Data/Prateek/VNP46A2/index.html.tmp’
#
# index.html.tmp      100%[===================>]  83.25K  --.-KB/s    in 0.06s
#
# Last-modified header missing -- time-stamps turned off.
# 2023-01-25 16:33:53 (1.44 MB/s) - ‘gdrive/MyDrive/CUSP Capstone Power Outage/Data/Prateek/VNP46A2/index.html.tmp’ saved [85250/85250]
#
# Removing gdrive/MyDrive/CUSP Capstone Power Outage/Data/Prateek/VNP46A2/index.html.tmp since it should be rejected.
#
# ...

# %%
'''
Next step go to processing notebook and save as tiff files
'''
# Out:
# '\nNext step go to process and save as tiff files\n'
